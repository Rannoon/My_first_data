# %%
# Task 1
int1 = 6
print (int1,type(int1))
float1 = 2.5
print (float1,type(float1))
str1 ="hi"
print (str1,type(str1))
bool1 = True
print (bool1,type(bool1))
# Out:
# 6 <class 'int'>
# 2.5 <class 'float'>
# hi <class 'str'>
# True <class 'bool'>

# %%
#Task 2
text = " Hello MoM"

print(text.replace("MoM","DaD"))
print (text.lower())
print (text,list(text))
# Out:
#  Hello DaD
#  hello mom
#  Hello MoM [' ', 'H', 'e', 'l', 'l', 'o', ' ', 'M', 'o', 'M']

# %%
#Task 3 :
x = 7
y = 2.5
print (x,y,x+y,x-y,x*y,x//y, x%y,y**x)
print (x>y)
print (y>x)
print(x>=7,x==y ,x!=y )
# Out:
# 7 2.5 9.5 4.5 17.5 2.0 2.0 610.3515625
# True
# False
# True False True
